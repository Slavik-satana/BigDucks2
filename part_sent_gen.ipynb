# %%
import pandas as pd
import numpy as np
import string
from random import sample
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

from IPython.display import clear_output

import matplotlib.pyplot as plt

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('{} device is available'.format(device))
# Out:
# cuda device is available

# %%
df = pd.read_excel('hackaton_result_dataset.xlsx')

# %%
df_for_dict = df['human_markup']
df_for_generation = df['model_annotation']

# %% [markdown]
# >***Предобработка текстов (и того, из которого собираем словарь, и того, который будем догенерировать)***

# %%
import re
import numpy as np
from gensim.corpora.dictionary import Dictionary
from razdel import tokenize 
import pymorphy2
import nltk
from nltk.corpus import stopwords

# %%
morph = pymorphy2.MorphAnalyzer() # перевод слова в исходную форму

# %%
nltk.download('stopwords')
stopword_ru = stopwords.words('russian')
# Out:
# 151
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\olg-k\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# т.к. предложенный текст сам по себе несет слабую смысловую нагрузку, то стандартный nltk список русских стоп-слов убирает из фразы 2/3, сделала усеченный
stopword_ru_short = []
for _ in stopword_ru:
    if len(_) < 3:
        stopword_ru_short.append(_)

# %%
# визуально все строки уже приведены к нижнему регистру и из них уадалены небуквенные символы (знаки препинания и т.д.),
# поэтому этап очистки текстов опустим и перейдем к лемматизации

cache = {}
morph = pymorphy2.MorphAnalyzer()

def lemmatization(text):
    # переводим зашедший текст в строку
    if not isinstance(text, str):
        text = str(text)

    # делим на слова пришедшую строку 
    tokens = list(tokenize(text))
    words = [_.text for _ in tokens]

    # собственно лемматизация слов 
    words_lem = []
    for word in words:
        if len(word) > 1:  # для слов длиной в 1 символ не имеет смысла
            if word in cache: # чтобы не повторяться
                words_lem.append(cache[word])
            else: 
                temp_cach = cache[word] = morph.parse(word)[0].normal_form
                words_lem.append(temp_cach)

    # выкидываем стоп-слова
    words_lem_without_stopwords = [i for i in words_lem if not i in stopword_ru_short]

    return words_lem_without_stopwords

# %%
# %%time
from tqdm import tqdm
tqdm.pandas()

# применяем лемматизацию к обоим частям нашего текста
df_for_dict = df_for_dict.progress_apply(lambda x: lemmatization(x))
df_for_generation = df_for_generation.progress_apply(lambda x: lemmatization(x))
# Out:
# 100%|██████████| 6508/6508 [00:01<00:00, 6213.45it/s]
# 100%|██████████| 6508/6508 [00:00<00:00, 9746.19it/s]
# CPU times: total: 172 ms
# Wall time: 1.72 s

# %% [markdown]
# >***Обучение модели на текстах, размеченных человеком***

# %%
# функция для добавления меток начала и конца предложения
def add_start_finish(df):
    for i in df:
        i.insert(0, '<sos>')
        i.append('<eos>')
    return df

# %%
df_for_dict_s_f = df_for_dict.to_list()
df_for_dict_s_f = add_start_finish(df_for_dict_s_f)

df_for_generation_s_f = df_for_generation.to_list()
df_for_generation_s_f = add_start_finish(df_for_generation_s_f)

# %%
# Создадим словарь из обучаещего набора
common_dictionary = Dictionary(df_for_dict.to_list())
common_corpus = [common_dictionary.doc2bow(text) for text in df_for_dict.to_list()]

# %%
common_dictionary.add_documents([['<sos>'], ['<eos>'], ['<pad>']])

# %%
len(common_dictionary) #размер входного слоя
# Out:
# 5518

# %%
# Выравниваем длины векторов для батча
def to_matrix(df_for_dict_s_f, max_len=None, pad=common_dictionary.doc2idx(['<pad>'])[0], dtype='int32', batch_first=True): 
    max_len = max_len or max(map(len, df_for_dict_s_f))
    max_len += 1
    names_ix = np.zeros([len(df_for_dict_s_f), max_len], dtype) + pad
    names_ix[:, 0] = common_dictionary.doc2idx(['<sos>'])[0]

    for i in range(len(df_for_dict_s_f)):
        line_ix = common_dictionary.doc2idx(df_for_dict_s_f[i])
        names_ix[i, 1:len(line_ix)] = line_ix[1:]
        names_ix[i, len(line_ix)] = common_dictionary.doc2idx(['<eos>'])[0]

        
    if not batch_first: 
        names_ix = np.transpose(names_ix)

    return names_ix

# %%
# для теста пока возьмем GRU - RNN 
class GruRnn(nn.Module):
    def __init__(self, num_tokens = len(common_dictionary), emb_size = 18, hidden_size = 64, n_layers=1):
        super(GruRnn, self).__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.emb_size = emb_size

        self.encoder = nn.Embedding(num_tokens, emb_size)
        self.gru = nn.GRU(emb_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, num_tokens)

    def forward(self, input, hidden):
        input_enb = self.encoder(input)
        output, hidden = self.gru(input_enb[None, :, :], hidden)
        output = self.decoder(output)
        return output, hidden

    def init_hidden(self, batch_size):
        return Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size))

# %%
model_grurnn = GruRnn()

# %%
# цикл запуска модели
def rnn_loop(model_grurnn, batch_ix):

    batch_size, max_length = batch_ix.size()
    hid_state = model_grurnn.init_hidden(batch_size)
    logits = []

    for x_t in batch_ix.transpose(0,1):
        logits_next, hid_state = model_grurnn(x_t, hid_state)  
        logits.append(logits_next)
        
    return torch.stack(logits, dim=1)

# %%
max_length_ = max(map(len, df_for_dict_s_f))
max_length_
# Out:
# 46

# %%
# обучение модели

from IPython.display import clear_output
from random import sample

model_grurnn = GruRnn()
opt = torch.optim.Adam(model_grurnn.parameters())
loss_func = nn.CrossEntropyLoss(ignore_index=common_dictionary.doc2idx(['<pad>'])[0])

history = []

for i in range(1000):
    batch_ix = to_matrix(sample(df_for_dict_s_f, 32), max_len=max_length_)
    batch_ix = torch.tensor(batch_ix, dtype=torch.int64)
    
    logits_seq = rnn_loop(model_grurnn, batch_ix).permute(0,2,1,3)
    
    # compute loss
    predictions_logits = logits_seq[:, :, :-1]
    actual_next_tokens = batch_ix[:, 1:]
    
    loss = loss_func(
    predictions_logits.reshape((-1, len(common_dictionary))),
    actual_next_tokens.reshape(-1)
    )

    loss.backward()
    opt.step()
    
    opt.zero_grad()
    
    history.append(loss.data.numpy())
    if (i+1)%100==0:
        clear_output(True)
        plt.plot(history,label='loss')
        plt.legend()
        plt.show()

assert np.mean(history[:10]) > np.mean(history[-10:]), "RNN didn't converge."

# %% [markdown]
# > ***Генерация текста (генерация окончания фразы по первой половине)***

# %%
# Генерация текста

def generate_sample(model_grurnn, seed_phrase, max_length, temperature=1.0):
    
    x_sequence = common_dictionary.doc2idx(seed_phrase)
    x_sequence = [0 if x == -1 else x for x in x_sequence]       
    x_sequence = torch.tensor([x_sequence], dtype=torch.int64)
    hid_state = model_grurnn.init_hidden(batch_size=1)
    
    for i in range(len(seed_phrase) - 1):
        _, hid_state = model_grurnn(x_sequence[:, i], hid_state)
    
    # generating
    for _ in range(max_length - len(seed_phrase)):
        logits_next, hid_state = model_grurnn(x_sequence[:, -1], hid_state)
        p_next = F.softmax(logits_next / temperature, dim=-1).data.numpy()[0][0]
        p_next = p_next[2:5517]
        p_next = p_next + (1 - sum(p_next)) / len(p_next)
        next_ix = np.random.choice(np.arange(2, len(common_dictionary)-1), p=p_next)
        next_ix = torch.tensor([[next_ix]], dtype=torch.int64)
        x_sequence = torch.cat([x_sequence, next_ix], dim=1)
        # if next_ix == common_dictionary.doc2idx(['<eos>'])[0]:
        #   break
    return ' '.join([common_dictionary.id2token[ix] for ix in x_sequence.data.numpy()[0]])

# %%
df['Generated text'] = np.nan

# %%
df['Generated_enb'] = np.nan
df['Start_enb'] = np.nan
df['cosin_similarity'] = np.nan

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
for i in range(0, len(df_for_generation)):
    if len(df_for_generation[i]) > 2:
        df['Generated text'][i] = generate_sample(
            model_grurnn,
            seed_phrase = df_for_generation[i][0:(len(df_for_generation[i])//2 + 1)],
            max_length = len(df_for_generation[i]) - 1,
            temperature = 0.5  
        )
    else:
        df['Generated text'][i] = df_for_generation[i]

# %%
df['Start_enb'] = df.apply(lambda row: common_dictionary.doc2idx(df_for_generation[row.name]), axis=1) # эмбединги машинного изначального текста

# %%
# служебная функция
def str_to_emb(row):
    m = df['Generated text'][row]
    if type(m) == list:
       return common_dictionary.doc2idx(m)
    else:
        k = m.split()
        return common_dictionary.doc2idx(k)

# %%
df['Generated_enb'] = df.apply(lambda row: str_to_emb(row.name), axis=1) # эмбединги сгенерированного текста

# %%
# косинусное расстояние
import itertools
def cosin_similarity(row):
    a = df['Generated_enb'][row]
    b = df['Start_enb'][row]
    if len(a) == len(b):
        return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
    elif len(a) > len(b):
        m = [0]*len(a)
        n = [x + y for x, y in itertools.zip_longest(m, b, fillvalue=0)]
        return np.dot(a, n) / (np.linalg.norm(a) * np.linalg.norm(n))
    elif len(a) < len(b):
        m = [0]*len(b)
        n = [x + y for x, y in itertools.zip_longest(m, a, fillvalue=0)]
        return np.dot(n, b) / (np.linalg.norm(n) * np.linalg.norm(b))

# %%
df['cosin_similarity'] = df.apply(lambda row: cosin_similarity(row.name), axis=1)

# %%
df[40:70]
# Out:
#                                      model_annotation  \
# 40                               я спросил у меня нет
# 41                                 номер нет этот дом
# 42                               про военной сбор пел
# 43                                          что такой
# 44                                ты мне чего звонишь
# 45              туда подлей тебя и нету на свете даже
# 46                          любой допреза ваши деньги
# 47                ну вы дежурные что я должна сделать
# 48  да это страшно ты же мне что то там э ну тоже ...
# 49                                     какому времени
# 50                        ну это в принципе в грозном
# 51  ну вам откуда на получение информацию что нужн...
# 52                    алле але робот и слушаю жениева
# 53           да ну вот вооот видишь аблохи у тебя нет
# 54    и так с ветерком и синами доезжают они до киева
# 55                             а кто говорит простите
# 56                           ну я говорю конфет взять
# 57                                мой а как мой номер
# 58                  слушаю вас говорите что вы хотите
# 59                                        алкоресенко
# 60                                       в республика
# 61  ислам если бы не было ислама не было бы и если...
# 62                               что там нажал что ли
# 63                                        какого года
# 64                         вам передали приказание да
# 65                                             за мне
# 66                       слышишь долги слушай сюда мы
# 67                                      можете помочь
# 68  видите значит справо от вас будет ресторан доб...
# 69                                      нет я юзерная
#
#                                          human_markup  \
# 40                              ты спросил у меня нет
# 41                                  номер нет это дом
# 42                              про военные сборы пел
# 43                                       ты кто такой
# 44                                  ты мне чё звонишь
# 45             ну да подлей тебя и нету на свете даже
# 46                        любой каприз за ваши деньги
# 47              ну вы дежурный и что я должна сделать
# 48  тааак это страшно ты же мне шо то там эээ ну т...
# 49                                     какому времени
# 50                      нууу это в принципе в грозном
# 51  кто вам откуда вы получили информацию что нужн...
# 52                 алё алё ром привет слушай это женя
# 53          да ну вооот вот видишь а блохи у тебя нет
# 54  и так с ветерком и с песнями доезжают они до к...
# 55                             а кто говорит простите
# 56                           ну я говорю конфет взять
# 57                    вы эээ ааа а как вы мммой номер
# 58                  слушаю вас говорите что вы хотите
# 59                              а полковник борисенко
# 60                        в республиканский военкомат
# 61  ислама если бы не было ислама не было бы игила...
# 62                         ты что там нажрался что ли
# 63                                        какого года
# 64                         вам передали приказания да
# 65                                          ну вы мне
# 66  слышишь долбаёб слушай сюда тот факт что мы с ...
# 67                                тааак можете помочь
# 68  видите значит справа от вас будет ресторан доб...
# 69                                     нет я дежурная
#
#                                            audio_path  label  \
# 40  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 41  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 42  s3://ap-training-set/xacaton_openstt/part_1/05...      1
# 43  s3://ap-training-set/xacaton_openstt/part_1/05...      1
# 44  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 45  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 46  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 47  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 48  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 49  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 50  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 51  s3://ap-training-set/xacaton_openstt/part_1/05...      1
# 52  s3://ap-training-set/xacaton_openstt/part_1/05...      1
# 53  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 54  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 55  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 56  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 57  s3://ap-training-set/xacaton_openstt/part_1/29...      1
# 58  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 59  s3://ap-training-set/xacaton_openstt/part_1/05...      1
# 60  s3://ap-training-set/xacaton_openstt/part_1/29...      1
# 61  s3://ap-training-set/xacaton_openstt/part_1/29...      1
# 62  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 63  s3://ap-training-set/xacaton_openstt/part_1/05...      0
# 64  s3://ap-training-set/xacaton_openstt/part_1/29...      0
# 65  s3://ap-training-set/xacaton_openstt/part_1/29...      1
# 66  s3://ap-training-set/xacaton_openstt/part_1/29...      1
# 67  s3://ap-training-set/xacaton_openstt/part_1/29...      0
# 68  s3://ap-training-set/xacaton_openstt/part_1/29...      0
# 69  s3://ap-training-set/xacaton_openstt/part_1/29...      0
#
#                                        Generated text  \
# 40                                 <sos> спросить нет
# 41                        <sos> номер нет этот отвече
# 42                 <sos> про военный сбор поклониться
# 43                                    <sos> что такой
# 44                                  <sos> что звонить
# 45        <sos> туда подлить нету засекретить вложить
# 46                         <sos> любой <eos> ваш скот
# 47              <sos> дежурный что должный попытаться
# 48  <sos> это страшно что там тоже логично металли...
# 49                                  <sos> какой время
# 50                            <sos> это принцип быдло
# 51  <sos> откуда получение информация что известно...
# 52           <sos> алла але <eos> объединить двадцать
# 53                 <sos> вот вооот видеть хуёво тайна
# 54    <sos> так ветерок <eos> доезжать сухой поумнеть
# 55                            <sos> кто говорить тёща
# 56                   <sos> говорить конфета сиреневый
# 57                          <sos> мой как мой пожалуй
# 58                   <sos> слушать говорить что угууа
# 59                                        <sos> <eos>
# 60                                   <sos> республика
# 61  <sos> ислам если быть ислам быть если утинскай...
# 62                     <sos> что там нажать подъехать
# 63                                    <sos> какой год
# 64                          <sos> передать приказание
# 65                                     [<sos>, <eos>]
# 66             <sos> слышать долг слушать восемьдесят
# 67                                  <sos> мочь помочь
# 68  <sos> видеть значит <eos> быть утинскай разводить
# 69                                    <sos> нет <eos>
#
#                                         Generated_enb  \
# 40                                       [1, 155, 22]
# 41                             [1, 39, 22, 144, 3800]
# 42                           [1, 158, 156, 159, 4561]
# 43                                       [1, 13, 160]
# 44                                        [1, 13, 17]
# 45                     [1, 449, 163, 162, 1393, 1726]
# 46                              [1, 55, 0, 165, 3149]
# 47                             [1, 33, 13, 168, 3349]
# 48        [1, 47, 171, 13, 86, 173, 2831, 3200, 5335]
# 49                                      [1, 170, 174]
# 50                                  [1, 47, 176, 496]
# 51                  [1, 48, 958, 177, 13, 2147, 1837]
# 52                       [1, 1705, 3933, 0, 133, 425]
# 53                       [1, 15, 185, 184, 1741, 650]
# 54                   [1, 11, 186, 0, 187, 4017, 2962]
# 55                                  [1, 30, 38, 5378]
# 56                                 [1, 38, 192, 1798]
# 57                            [1, 233, 19, 233, 4147]
# 58                             [1, 140, 38, 13, 3334]
# 59                                             [1, 0]
# 60                                           [1, 483]
# 61  [1, 202, 199, 54, 202, 54, 199, 3477, 207, 823...
# 62                             [1, 13, 86, 3318, 945]
# 63                                      [1, 170, 207]
# 64                                      [1, 208, 209]
# 65                                             [1, 0]
# 66                          [1, 212, 1223, 140, 1047]
# 67                                       [1, 56, 215]
# 68                     [1, 184, 5, 0, 54, 3477, 4687]
# 69                                         [1, 22, 0]
#
#                                             Start_enb  cosin_similarity
# 40                                    [1, 155, 22, 0]          1.000000
# 41                            [1, 39, 22, 144, 16, 0]          0.144855
# 42                         [1, 158, 156, 159, 157, 0]          0.549324
# 43                                    [1, 13, 160, 0]          1.000000
# 44                                     [1, 13, 17, 0]          1.000000
# 45                    [1, 449, 163, 162, 164, 161, 0]          0.603392
# 46                           [1, 55, -1, 165, 166, 0]          0.729265
# 47                           [1, 33, 13, 168, 169, 0]          0.737041
# 48         [1, 47, 171, 13, 86, 173, 38, 158, 170, 0]          0.659073
# 49                                   [1, 170, 174, 0]          1.000000
# 50                               [1, 47, 176, 175, 0]          0.898925
# 51                  [1, 48, 958, 177, 13, 178, -1, 0]          0.449337
# 52                    [1, 1705, 3933, -1, 140, -1, 0]          0.995101
# 53                       [1, 15, 185, 184, -1, 22, 0]          0.164289
# 54                 [1, 11, 186, -1, 187, 115, 188, 0]          0.633320
# 55                                [1, 30, 38, 190, 0]          0.971207
# 56                               [1, 38, 192, 191, 0]          0.771762
# 57                           [1, 233, 19, 233, 39, 0]          0.195765
# 58                           [1, 140, 38, 13, 195, 0]          0.826536
# 59                                         [1, -1, 0]          0.707107
# 60                                        [1, 483, 0]          1.000000
# 61  [1, 202, 199, 54, 202, 54, 199, 54, 202, 54, 4...          0.177395
# 62                           [1, 13, 86, 3318, 13, 0]          0.962843
# 63                                   [1, 170, 207, 0]          1.000000
# 64                                   [1, 208, 209, 0]          1.000000
# 65                                             [1, 0]          1.000000
# 66                        [1, 212, 1223, 140, 213, 0]          0.863461
# 67                                    [1, 56, 215, 0]          1.000000
# 68                   [1, 184, 5, -1, 54, 217, 216, 0]          0.854958
# 69                                     [1, 22, -1, 0]          0.998971

# %%
# доработка: взять предобученные эмбединги (например из BERT), дополнить своим словарем, составленным из нашей выборки. 
# у того же  BERT есть такое применение как Masked Language Modelling (предсказание замаскированного слова) - возможно это то, что нам нужно
